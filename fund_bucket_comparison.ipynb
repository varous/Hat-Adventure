# %% [markdown]
# <a href="https://colab.research.google.com/github/varous/Hat-Adventure/blob/main/fund_bucket_comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MEMORANDUM: PORTFOLIO ALLOCATION & RISK ANALYSIS
#
# INVESTMENT CONSTRAINTS & CASH FLOW MANDATE
# - Principal: INR 28,00,000
# - Required Withdrawal: INR 20,000 – INR 24,000 / month (INR 2.40L – INR 2.88L annually)
# - Initial Withdrawal Rate: 8.57% – 10.28% p.a.
# - Investor Profile: 55-year-old, Low-to-Moderate Risk, Primary Goal: Capital Preservation + Cash Flow Sustainability
#
# ================================================================================
# 1. COMPARATIVE METRICS MATRIX (HISTORICAL 3Y/5Y CATEGORY PROXIES)
# ================================================================================
#
# Metric / Attribute             Bucket 1 (BAF Heavy)          Bucket 2 (Multi Cap + Hybrid Mix)
# --------------------------------------------------------------------------------
# Asset Allocation Architecture   Dynamic (Net Eq 30%-65%)      Unhedged Eq Heavy (Net Eq 65%-85%)
# Small + Mid Cap Exposure       Typically < 15%               Mandatory >= 50% (via Multi Cap)
# Portfolio Standard Deviation    7.5% – 9.5%                   13.5% – 16.5%
# Sharpe Ratio (Risk-Adjusted)    0.85 – 1.10                   0.60 – 0.75
# Worst Historical Drawdown      -8% to -12% (controlled)      -22% to -35% (elevated beta)
# Downside Capture Ratio         35% – 50%                     75% – 90%
# Tax Treatment                  Equity (>65% Gross)           Equity (>65% Gross)
# Suitability for >8.5% SWP      Viable with low destruction   High Failure Rate via Rupee Destocking
#
# ================================================================================
# 2. THE CORE PROBLEM WITH BUCKET 2: SEVERE SEQUENCE OF RETURNS RISK (SRR)
# ================================================================================
#
# 1. Mandatory Mid/Small Cap Mandate (SEBI Multi Cap Rule):
#    - SEBI regulations require Multi Cap funds to maintain minimum 25% in Mid Caps and 25% in Small Caps at all times, regardless of market valuations.
#    - For an 8.57%–10.28% withdrawal rate, running a high-beta portfolio exposes the capital to deep corrections.
#
# 2. Mechanics of Rupee Destocking under SWP:
#    - If Bucket 2 experiences a standard 20% drawdown in Year 1:
#      * Corpus drops: INR 28.00L -> INR 22.40L.
#      * Annual SWP payout: INR 2.88L (INR 24k/mo).
#      * Effective withdrawal rate surges from 10.28% to 12.85% on reduced capital.
#      * Capital erosion becomes mathematically irreversible without unrealistic equity outperformance (>18% CAGR).
#
# 3. Downside Capture vs. Income Generation:
#    - Bucket 1 (Balanced Advantage) cuts net equity during overvalued markets via derivative hedging and arbitrage, capturing only 35%-50% of market downside while retaining equity taxation.
#    - Bucket 2 captures 75%-90% of market downside, forcing the liquidation of higher unit volumes at cycle lows to service fixed monthly cash flows.
#
# ================================================================================
# 3. CONCLUSION & DIRECTIVE
# ================================================================================
# Bucket 2 introduces structural volatility incompatible with an immediate 8.5%+ SWP requirement.
#
# Recommendation:
# - Reject Bucket 2 entirely for immediate income generation.
# - Proceed with Bucket 1 (Dynamic Asset Allocation / BAF) or a segregated Two-Tier Bucket Architecture (Arbitrage/Liquid buffer for 2-year SWP runway + BAF for core compounding).
